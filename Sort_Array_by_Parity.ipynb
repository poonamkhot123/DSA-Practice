# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Sort_Array_by_Parity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# given an integer array nums, move all the even integers
# at the beginning of the array followed by all the odd integers.

# %%
class Solution:
  def sortArrayByParity(self, nums):
    start = 0

    for i in range(len(nums)):
      if nums[i] % 2 == 0:
        temp  = nums[i]
        nums[i] = nums[start]
        nums[start] = temp
        start += 1
    return nums

# %%
nums  = [3,1,2,4]
Solution().sortArrayByParity(nums)
# Out:
# [2, 4, 3, 1]
