# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def printHi():
  print("hii")
printHi()

# %%
def printHi():
  name = "poonam khot"
  print(name)

print("before function calling....")

printHi()

print("after function call....")
# Out:
# before function calling....
# poonam khot
# after function call....

# %%
# function without parameter...
def greetings():
  print("welcome to python tutorial by Poonam")
greetings()
# Out:
# welcome to python tutorial by Poonam

# %%
def add2numbers(a,b):
  result = a+b
  print("The sum is:",result)
add2numbers(5,3)
# Out:
# The sum is: 8

# %%
def add(a,b):
  return a+b
  print("addition of two numbers:")
add(6,7)
# Out:
# 13

# %%
# call above sum function...
add(a=30,b=67)
# Out:
# 97

# %%
add(b=45,a=67)
# Out:
# 112

# %%
def add3numbers(a,b,c):
  result = a+b+c
  print("The sum is:",result)
add3numbers(45,34,66)
# Out:
# The sum is: 145

# %%
# function with return statment...

# %%
def celsuis_to_fahrenheit(celsius):
  fahrenheit = (celsius * 9/5) + 32
  return fahrenheit

# %%
a =celsuis_to_fahrenheit(25)
print(a)
# Out:
# 77.0
