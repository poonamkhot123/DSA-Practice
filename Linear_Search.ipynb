# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Linear_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# linear Search

# %%
def search(nums,target):
  n = len(nums)
  for i in range(n):
    if nums[i] == target:
      return i
  return -1

# %%
nums = [4,5,6,3,2,4,6,7,8]
search(nums,2)
# Out:
# 4

# %%
def search(nums,target):
  n = len(nums)
  for i in range(n):
    if nums[i] == target:
      return i
  return -1

# %%
nums = [7,8,9,5,43,6]
search(nums,6)
# Out:
# 5
