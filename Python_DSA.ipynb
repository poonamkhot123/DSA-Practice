# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Python_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 10
if n %2 == 0:
  print("It is even number")
# Out:
# It is even number

# %%
# count the number of digits in an interger.
n = 5438
num = n
count = 0
while num >0:
  count += 1
  num = num // 10
print(count)

# %%
# check the palindrome number
def Cpalindrome(n):
    original_n = n
    num = n
    result = 0
    while num > 0:
        digit = num % 10
        result = (result * 10) + digit
        num = num // 10
    return original_n == result
