# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/DSA_with_College_wallah_(lecture_4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set

# %%
set1 = {2,4,"hello",2,"abhinav"}

# %%
print(set1)
# Out:
# {2, 4, 'abhinav', 'hello'}

# %%
list1 = [3,4,5,3,433,5,4,2,45,6,7,8]
set1 = set(list1)

# %%
set1 = {"hello",2,4,"abhinav"}
set1.add(100)

# %%
set1
# Out:
# {100, 2, 4, 'abhinav', 'hello'}

# %%
set1.discard("hello")

# %%
set1
# Out:
# {100, 2, 4, 'abhinav'}

# %%
set1 = {"hello",2,4,"abhinav"}
if "hii" in set1:
  print(True)
else:
  print(False)
# Out:
# False

# %%
print(set1)
# Out:
# {2, 4, 'abhinav', 'hello'}

# %%
set1 = {1,2,3}
set2 = set1
set2.add(4)

# %%
print(set1)
# Out:
# {1, 2, 3, 4}

# %%
print(set2)
# Out:
# {1, 2, 3, 4}

# %%
set1 = {1,8,5,2,4}
set2 = {8,2,9,6}
set1.union(set2)
# Out:
# {1, 2, 4, 5, 6, 8, 9}

# %%
set1 | set2
# Out:
# {1, 2, 4, 5, 6, 8, 9}

# %%
set1.intersection(set2)
# Out:
# {2, 8}

# %%
set1.difference(set2)
# Out:
# {1, 4, 5}

# %%
set1-set2
# Out:
# {1, 4, 5}

# %%
set2^set1
# Out:
# {1, 4, 5, 6, 9}

# %%
# dictionary

# %%
dict1 = {1:'abhinav','hello':100,10.21:'hii','key':True}

# %%
print(dict1)
# Out:
# {1: 'abhinav', 'hello': 100, 10.21: 'hii', 'key': True}

# %%
print(dict1['hello'])
# Out:
# 100

# %%
print(dict1)
# Out:
# {1: 'abhinav', 'hello': 100, 10.21: 'hii', 'key': True}

# %%
dict1 = {1:"abhinav",2:"aman",3:"Rahul",4:"yash"}

# %%
print(dict1)
# Out:
# {1: 'abhinav', 2: 'aman', 3: 'Rahul', 4: 'yash'}

# %%
dict1[5] = "yash"

# %%
dict1
# Out:
# {1: 'abhinav', 2: 'aman', 3: 'Rahul', 4: 'yash', 5: 'yash'}

# %%
dict1[2] = "abhi"

# %%
dict1
# Out:
# {1: 'abhinav', 2: 'abhi', 3: 'Rahul', 4: 'yash', 5: 'yash'}

# %%
dict1 = {1:"abhinav",2:"aman",3:"rahul",4:"yash"}
for key, value in dict1.items():
  print(key,value)
# Out:
# 1 abhinav
# 2 aman
# 3 rahul
# 4 yash

# %%
print(dict1.keys())
for key in dict1.keys():
    print(key,value)
# Out:
# dict_keys([1, 2, 3, 4])
# 1 yash
# 2 yash
# 3 yash
# 4 yash

# %%
print(dict1.keys())
for key in dict1.keys():
    print(key)
# Out:
# dict_keys([1, 2, 3, 4])
# 1
# 2
# 3
# 4

# %%
print(dict1.values())

# %%
list1 = ["abihnav","aman","abhinav","yash","aman","abhinav","yash"]
freq = {}
