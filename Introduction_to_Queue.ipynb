# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Introduction_to_Queue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Introduction to Queue....

# %%
"""Queue is a Linear data structure that follows
FIFO (First in first out) principle,so the first element
inserted is the first to be popped out."""
# Out:
# 'Queue is a Linear data structure that follows\nFIFO (First in first out) principle,so the first element \ninserted is the first to be popped out.'

# %%
# Basic operations of Queue..
1. push
2. pop
3. front
4. isEmpty
5. isFull
