# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Valid_Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [4,5,6,3,4,56]
class Solution:
  def print(nums,a,b):
    return a+b

# %%
print()

# %%
s = "madam"

if s == s[::-1]:
  print("Palindrome")
else:
  print("Not palindrome")
# Out:
# Palindrome

# %%
s = "madam"

if s == s[::-1]:
  print("Palindrome")
else:
  print("Not palindrome")
# Out:
# Palindrome

# %%
s = "madam"

if s == s[::-1]:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# palindrome

# %%
s = "madam"
reverse = ""

for i in range(len(s)-1,-1,-1):
  reverse = reverse +s[i]

if s == reverse:
  print("Palindrome")
else:
  print("not palindrome")
# Out:
# Palindrome

# %%
s = "madam"
reverse = ""

for i in range(len(s)-1,-1,-1):
  reverse = reverse + s[i]

if s == reverse:
  print("Palindrome")
else:
  print("Not palindrome")
# Out:
# Palindrome

# %%
s = "madam"
reverse = ""

for i in range(len(s)-1,-1,-1):
  reverse = reverse + s[i]
if s == reverse:
  print("palindrome")
else:
  print("Not palindrome")

# %%
s = "madam"

reverse = ""

for i in range(len(s)-1,-1,-1):
  reverse = reverse + s[i]
if s == reverse:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# palindrome
