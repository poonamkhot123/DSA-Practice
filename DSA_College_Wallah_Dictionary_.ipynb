# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/DSA_College_Wallah_Dictionary_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# dictionary

# %%
dict1 = {1:"abhinav",2:"aman",3:"Rahul",4:"yash"}
dict2 = dict1

dict2[100] = "hello"

print(dict1)
print(dict2)
# Out:
# {1: 'abhinav', 2: 'aman', 3: 'Rahul', 4: 'yash', 100: 'hello'}
# {1: 'abhinav', 2: 'aman', 3: 'Rahul', 4: 'yash', 100: 'hello'}

# %%
dict1 = {1:"abhinav",2:"aman",3:"Rahul",4:"yash"}
for key,value in dict1.items():
  print(key,value)
# Out:
# 1 abhinav
# 2 aman
# 3 Rahul
# 4 yash

# %%
print(dict1.items())

# %%
for key in dict1.keys():
  print(key)
# Out:
# 1
# 2
# 3
# 4

# %%
for value in dict1.values():
  print(value)
# Out:
# abhinav
# aman
# Rahul
# yash

# %%
s = "physics wallah skills..."
freq = {}
for name in s:
  if name not in freq:
    freq[name] = 1
  else:
    freq[name] += 1

# %%
print(freq)
# Out:
# {'p': 1, 'h': 2, 'y': 1, 's': 4, 'i': 2, 'c': 1, ' ': 2, 'w': 1, 'a': 2, 'l': 4, 'k': 1, '.': 3}

# %%
s = "physics wallah skills"
freq = {}
for name in s:
  if name not in freq:
    freq[name] = 1
  else:
     freq[name] += 1

# %%
s = "Physics wallah skills"
freq = {}
for name in s:
  if name not in freq:
    freq[name] = 1
  else:
    freq[name] += 1

# %%
print(freq)
# Out:
# {'P': 1, 'h': 2, 'y': 1, 's': 4, 'i': 2, 'c': 1, ' ': 2, 'w': 1, 'a': 2, 'l': 4, 'k': 1}
