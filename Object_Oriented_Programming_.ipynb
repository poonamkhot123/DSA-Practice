# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Object_Oriented_Programming_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_grade(marks):
  return "A" if marks > 80 else "B"
student_marks = 85

# %%
def cal(a,b):
  return a+b

# %%
cal(5,9)
# Out:
# 14
