# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Remove_Duplicates_from_Sorted_linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def deleteDuplicates(head):
  # corner cases
  if head == None or head.next == None:
    return head

  curr = head
  while curr != None and curr.next != None:
    # duplicate
    if curr.next.val == curr.val:
      curr.next = curr.next.next
    else:
      curr = curr.next

# %%
def deleteDuplicates(head):
  # corner cases
  if head == None or head.next == None:
    return head

  curr = head
  while curr != None and curr.next != None:
    # duplicate
    if curr.next.val == curr.val:
      curr.next = curr.next.next
    else:
      curr = curr.next

# %%
def deleteDuplicates(head):
  # corner cases
  if head == None or head.next == None:
    return head

  curr = head
  while curr != None and curr.next != None:
    # duplicate
    if curr.next.val == curr.next != None:
      curr.next = curr.next.next
    else:
      curr = curr.next
