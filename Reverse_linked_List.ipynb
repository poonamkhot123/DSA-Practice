# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/Reverse_linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# To reverse a linked list just reverse a links.

# %%
def reverseList(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    curr.next != prev
    prev = curr
    curr = nxt

# %%
def reverseList(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    curr.next != prev
    prev = curr
    curr = nxt

# %%
def reverseList(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    curr.next != prev
    prev = curr
    curr = nxt

# %%
def reverseList(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    curr.next != prev
    prev = curr
    curr = nxt

# %%
def reverseList(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    curr.next != prev
    prev = curr
    curr = nxt

# %%
def reverseList(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    curr.next != prev
    prev = curr
    curr = nxt

# %%
def reverseList(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    curr.next != prev
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr !=  None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr.next
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr.next
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr.next
    curr = nxt

# %%
def reverselist(head):
  curr = head
  prev = None
  nxt = None

  while curr != None:
    nxt = curr.next
    prev = curr.next
    curr = nxt
