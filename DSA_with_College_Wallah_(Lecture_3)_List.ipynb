# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/DSA-Practice/blob/main/DSA_with_College_Wallah_(Lecture_3)_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = ['poonam','aman','ravi','yash']
print(names)
print(type(names))
# Out:
# ['poonam', 'aman', 'ravi', 'yash']
# <class 'list'>

# %%
print(names[0])
# Out:
# poonam

# %%
print(names[1])
# Out:
# aman

# %%
print(names[2])
# Out:
# ravi

# %%
print(len(names))
# Out:
# 4

# %%
names[0] = "abhinav"

# %%
names
# Out:
# ['abhinav', 'aman', 'ravi', 'yash']

# %%
list1 = [5,"hello",34.23,True,214]

# %%
print(list1)
# Out:
# [5, 'hello', 34.23, True, 214]

# %%
list1 = [4,2,1,7,8,4,7]
list1.append(9)
list1.append(2)

# %%
list1.append([1,2,3])

# %%
list1
# Out:
# [4, 2, 1, 7, 8, 4, 7, 9, 2, [1, 2, 3]]

# %%
list1.extend([1,2,3])

# %%
list1
# Out:
# [4, 2, 1, 7, 8, 4, 7, 9, 2, [1, 2, 3], 1, 2, 3]

# %%
list1 = [32,6,2,42,35,12]
list1.insert(3,100)
print(list1)
# Out:
# [32, 6, 2, 100, 42, 35, 12]

# %%
list1.remove(42)
print(list1)

# %%
list1.pop(1)
# Out:
# 6

# %%
list1.clear()

# %%
print(min(list1))
# Out:
# 2

# %%
print(max(list1))
# Out:
# 100

# %%
list1 = [4,1,2,3,4,3,2,3,2,3,4,5,6,7,21,1,2,3,1,2]
print(list1.count(1))
# Out:
# 3

# %%
print(list1.sort())
# Out:
# None

# %%
print(list1)
# Out:
# [1, 1, 1, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 4, 4, 4, 5, 6, 7, 21]

# %%
list1.reverse()

# %%
list1 = [1,5,3,2,5,7,3]
print(list1.index(2))
# Out:
# 3

# %%
print(list1.index(5,3))
# Out:
# 4

# %%
list1 = [1,2,3]
list2 = list1

list2.append(4)
print(list1)
print(list2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
list1 = [1,2,3]
list2 = list1.copy()

list2.append(4)

print(list1,id(list1))
print(list2,id(list2))
# Out:
# [1, 2, 3] 140250795592960
# [1, 2, 3, 4] 140250381445248
# [1, 2, 3] 140251152528832
# [1, 2, 3, 4] 140250381478464

# %%
print(list1,id(list1))
print(list2,id(list2))
# Out:
# [1, 2, 3] 140250795592960
# [1, 2, 3, 4] 140250381445248
# [1, 2, 3] 140251152528832
# [1, 2, 3, 4] 140250381478464

# %%
list1 = [3,4,456,24,312,234,456,42,23]
list1[2:6]
# Out:
# [456, 24, 312, 234]

# %%
print(list1[2:8:3])
# Out:
# [456, 234]

# %%
print(list1[8:1:-2])
